# %%
import pyautogui as p
from PIL import Image,ImageGrab
import pytesseract
import cv2
import os
import keyboard
import time
from pathlib import Path
import numpy as np

# %%
time.sleep(2)
p.position()
# Out:
# Point(x=1342, y=593)

# %%
bbox=(0,214,1342,593)

# %%
def screen_grab(bbox):
    cap=ImageGrab.grab(bbox=bbox)
    img_np=np.array(cap)
    img=cv2.cvtColor(img_np,cv2.COLOR_RGB2BGR)
    cv2.imshow("image",img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
time.sleep(2)
screen_grab(bbox=bbox)

# %%
while keyboard.is_pressed('q') is False:
    cap=ImageGrab.grab(bbox=bbox)
    img_np=np.array(cap)
    img=cv2.cvtColor(img_np,cv2.COLOR_RGB2BGR)
    width,height=cap.size
    for x in range(0,width,5):
        for y in range(0,height,5):
            r,g,b=img.

# %%
while keyboard.is_pressed('q') is False:
    time.sleep(0.5)
    x,y=p.position()
    print(p.pixel(x,y))
# Out:
# (31, 31, 31)
# (31, 31, 31)
# (43, 135, 209)
# (43, 135, 209)
# (149, 195, 232)
# (149, 195, 232)
# (149, 195, 232)
# (149, 195, 232)
# (149, 195, 232)
# (149, 195, 232)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)
# (255, 255, 255)

# %%
color1=(255,255,255)
color2=(149,195,232)
