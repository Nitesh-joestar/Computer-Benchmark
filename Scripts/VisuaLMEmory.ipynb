# %% [markdown]
# i feeel like the way you solve it would be to takee lvl manually pick the cursor position go to nexxt lvl and do that and keep going.

# %%
import pyautogui as p
from PIL import Image,ImageGrab
import pytesseract
import cv2
import os
import keyboard
import time
from pathlib import Path
import numpy as np
