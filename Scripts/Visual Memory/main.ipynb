# %%
import numpy as np
import cv2
from PIL import ImageGrab
import pytesseract
import time
import keyboard
import pyautogui as p

# %%
p.position()
# Out:
# Point(x=666, y=549)

# %%
p.moveTo(666,549)
p.click()
level=1
