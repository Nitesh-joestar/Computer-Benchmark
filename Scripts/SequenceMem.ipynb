# %%
import pyautogui as p
from PIL import Image,ImageGrab
import pytesseract
import cv2
import os
import keyboard
import time
from pathlib import Path
import numpy as np

# %%
p.position()
# Out:
# Point(x=1092, y=303)

# %%
deck=[]

# %%
p1=(550,290)
p2=(682,291)
p3=(787,288)
p4=(538,442)
p5=(670,422)
p6=(786,418)
p7=(532,577)
p8=(666,562)
p9=(807,557)
white=(255,255,255)
startButton=(683,527)
#lasts 5 secs

# %%
deck=[]
deck.append(p1)
deck.append(p2)
deck.append(p3)
deck.append(p9)
deck.append(p1)
print(deck[0]!=deck[4])
# Out:
# False

# %%
def selectRow(deck):
    for i in deck:
        p.moveTo(*i,duration=0.2)
        p.click()
        p.moveTo(1092,303)

# %%
def placeFunction(number,tim,px):
    print(number)
    time.sleep(tim)
    deck.append(px)

# %%
p.moveTo(*startButton,duration=0.2)
p.click()
counter=0
toCount=1
tim=0.49
deck.clear()
while keyboard.is_pressed('q') is False:
    if p.pixel(*p1)==white:
        placeFunction(1,tim,p1)
        counter+=1
    elif p.pixel(*p2)==white:
        placeFunction(2,tim,p2)
        counter+=1
    elif p.pixel(*p3)==white:
        placeFunction(3,tim,p3)
        counter+=1
    elif p.pixel(*p4)==white:
        placeFunction(4,tim,p4)
        counter+=1
    elif p.pixel(*p5)==white:
        placeFunction(5,tim,p5)
        counter+=1        
    elif p.pixel(*p6)==white:
        placeFunction(6,tim,p6)
        counter+=1    
    elif p.pixel(*p7)==white:
        placeFunction(7,tim,p7)
        counter+=1  
    elif p.pixel(*p8)==white:
        placeFunction(8,tim,p8)
        counter+=1    
    elif p.pixel(*p9)==white:
        placeFunction(9,tim,p9)
        counter+=1
    if counter==toCount:
        counter=0
        #tim=0.475
        toCount+=1
        print("-------x-------")
        selectRow(deck)
        deck.clear()
# Out:
# 5
# -------x-------
# 5
# 8
# -------x-------
# 5
# 8
# 3
# -------x-------
# 5
# 8
# 3
# 7
# -------x-------
# 5
# 8
# 3
# 7
# 5
# -------x-------
# 5
# 8
# 3
# 7
# 5
# 1
# -------x-------
# 5
# 8
# 3
# 7
# 5
# 1
# 4
# -------x-------
# 5
# 8
# 3
# 7
# 5
# 1
# 4
# 2
# -------x-------
# 5
# 8
# 3
# 7
# 5
# 1
# 4
# 2
# 1
# -------x-------
# 5
# 8
# 3
# 7
# 5
# 1
# 4
# 2
# 1
# 3
# -------x-------
# 5
# 8
# 3
# 7
# 5
# 1
# 4
# 2
# 1
# 3
# 7
# -------x-------
# 5
# 8
# 3
# 7
# 5
# 1
# 4
# 2
# 1
# 3
# 7
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 26
#      24     placeFunction(6,tim,p6)
#      25     counter+=1
# ---> 26 elif p.pixel(*p7)==white:
#      27     placeFunction(7,tim,p7)
#      28     counter+=1
#
# File d:\Anaxonda\Lib\site-packages\pyscreeze\__init__.py:757, in pixel(x, y)
#     754 if sys.platform == 'win32':
# ...

# %% [markdown]
# with last before 0.4 went to 11

# %%
t=5
print(t)
def changeT(t):
    t=3
changeT(t)
print(t)
# Out:
# 5
# 5

# %% [markdown]
# New function

# %%
def newFtn(number,px,deck):
    print(number)
    deck.append(px)

# %%
deck.clear()
counter=0
p.moveTo(*startButton,duration=0.2)
p.click()
toCount=1
while True:
    if((counter ==0 and p.pixel(*p1)==white) or (p.pixel(*p1)==white and counter!=0 and deck[counter-1]!=p1)):
        counter+=1
        newFtn(1,p1,deck)
    elif((counter ==0 and p.pixel(*p2)==white) or (p.pixel(*p2)==white and counter!=0 and deck[counter-1]!=p2)):
        counter+=1
        newFtn(2,p2,deck)
    elif((counter ==0 and p.pixel(*p3)==white) or (p.pixel(*p3)==white and counter!=0 and deck[counter-1]!=p3)):
        counter+=1
        newFtn(3,p3,deck) 
    elif((counter ==0 and p.pixel(*p4)==white) or (p.pixel(*p4)==white and counter!=0 and deck[counter-1]!=p4)):
        counter+=1
        newFtn(4,p4,deck) 
    elif((counter ==0 and p.pixel(*p5)==white) or (p.pixel(*p5)==white and counter!=0 and deck[counter-1]!=p5)):
        counter+=1
        newFtn(5,p5,deck) 
    elif((counter ==0 and p.pixel(*p6)==white) or (p.pixel(*p6)==white and counter!=0 and deck[counter-1]!=p6)):
        counter+=1
        newFtn(6,p6,deck) 
    elif((counter ==0 and p.pixel(*p7)==white) or (p.pixel(*p7)==white and counter!=0 and deck[counter-1]!=p7)):
        counter+=1
        newFtn(7,p7,deck) 
    elif((counter ==0 and p.pixel(*p8)==white) or (p.pixel(*p8)==white and counter!=0 and deck[counter-1]!=p8)):
        counter+=1
        newFtn(8,p8,deck) 
    elif((counter ==0 and p.pixel(*p9)==white) or (p.pixel(*p9)==white and counter!=0 and deck[counter-1]!=p9)):
        counter+=1
        newFtn(9,p9,deck) 
    if counter==toCount:
        counter=0
        toCount+=1
        time.sleep(0.2)
        print("-------x-------")
        selectRow(deck)
        deck.clear()
# Out:
# 6
# -------x-------
# 6
# 7
# -------x-------
# 6
# 7
# 2
# -------x-------
# 6
# 7
# 2
# 9
# -------x-------
# 6
# 7
# 2
# 9
# 5
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# 1
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# 1
# 8
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# 1
# 8
# 7
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# 1
# 8
# 7
# 5
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# 1
# 8
# 7
# 5
# 4
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# 1
# 8
# 7
# 5
# 4
# 6
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# 1
# 8
# 7
# 5
# 4
# 6
# 9
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# 1
# 8
# 7
# 5
# 4
# 6
# 9
# 5
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# 1
# 8
# 7
# 5
# 4
# 6
# 9
# 5
# 3
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# 1
# 8
# 7
# 5
# 4
# 6
# 9
# 5
# 3
# 8
# -------x-------
# 6
# 7
# 2
# 9
# 5
# 6
# 7
# 1
# 8
# 7
# 5
# 4
# 6
# 9
# 5
# 3
# 8
# 4
# ...

# %%
deck.clear()
deck.append(p1)
deck.append(p2)
for i in deck:
    print(i)
def deckapp():
    deck.append(p5)
deckapp()
print("**")
for i in deck:
    print(i)
# Out:
# (550, 290)
# (682, 291)
# **
# (550, 290)
# (682, 291)
# (670, 422)

# %%
deck.clear()
deck[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 deck.clear()
# ----> 2 deck[0]
#
# IndexError: list index out of range
