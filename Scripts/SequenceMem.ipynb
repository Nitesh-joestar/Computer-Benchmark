# %%
import pyautogui as p
from PIL import Image,ImageGrab
import pytesseract
import cv2
import os
import keyboard
import time
from pathlib import Path
import numpy as np

# %%
p.position()
# Out:
# Point(x=1092, y=303)

# %%
deck=[]

# %%
p1=(550,290)
p2=(682,291)
p3=(787,288)
p4=(538,442)
p5=(670,422)
p6=(786,418)
p7=(532,577)
p8=(666,562)
p9=(807,557)
white=(255,255,255)
startButton=(683,527)
#lasts 5 secs

# %%
deck=[]
deck.append(p1)
deck.append(p2)
deck.append(p3)
deck.append(p9)
deck.append(p1)

# %%
def selectRow(deck):
    for i in deck:
        p.moveTo(*i,duration=0.2)
        p.click()
        p.moveTo(1092,303)

# %%
p.moveTo(*startButton,duration=0.2)
p.click()
counter=0
toCount=1
tim=0.4875
deck.clear()
while keyboard.is_pressed('q') is False:
    if p.pixel(*p1)==white:
        print('1')
        time.sleep(tim)
        deck.append(p1)
        counter+=1
    elif p.pixel(*p2)==white:
        print('2')
        deck.append(p2)
        counter+=1
        time.sleep(tim)
    elif p.pixel(*p3)==white:
        print('3')
        time.sleep(tim)
        deck.append(p3)
        counter+=1
    elif p.pixel(*p4)==white:
        print('4')
        time.sleep(tim)
        deck.append(p4)
        counter+=1
    elif p.pixel(*p5)==white:
        print('5')
        time.sleep(tim)
        deck.append(p5)
        counter+=1        
    elif p.pixel(*p6)==white:
        print('6')
        time.sleep(tim)
        deck.append(p6)
        counter+=1    
    elif p.pixel(*p7)==white:
        print('7')
        time.sleep(tim) 
        deck.append(p7)
        counter+=1  
    elif p.pixel(*p8)==white:
        print('8')
        deck.append(p8)
        time.sleep(tim)
        counter+=1    
    elif p.pixel(*p9)==white:
        print('9')
        time.sleep(tim) 
        deck.append(p9)
        counter+=1
    if counter==toCount:
        counter=0
        toCount+=1
        if toCount>7:
            tim=0.45
        print("-------x-------")
        selectRow(deck)
        deck.clear()
# Out:
# 2
# -------x-------
# 2
# 2
# -------x-------
# 2
# 2
# 2
# -------x-------
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# Cell In[84], line 59
#      57     tim=0.45
#      58 print("-------x-------")
# ---> 59 selectRow(deck)
#      60 deck.clear()
#
# Cell In[44], line 3, in selectRow(deck)
#       1 def selectRow(deck):
#       2     for i in deck:
# ----> 3         p.moveTo(*i,duration=0.2)
#       4         p.click()
#       5         p.moveTo(1092,303)
#
# File d:\Anaxonda\Lib\site-packages\pyautogui\__init__.py:593, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     591 @functools.wraps(wrappedFunction)
#     592 def wrapper(*args, **kwargs):
# --> 593     failSafeCheck()
#     594     returnVal = wrappedFunction(*args, **kwargs)
#     595     _handlePause(kwargs.get("_pause", True))
#
# File d:\Anaxonda\Lib\site-packages\pyautogui\__init__.py:1734, in failSafeCheck()
#    1732 def failSafeCheck():
#    1733     if FAILSAFE and tuple(position()) in FAILSAFE_POINTS:
# -> 1734         raise FailSafeException(
#    1735             "PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED."
#    1736         )
#
# FailSafeException: PyAutoGUI fail-safe triggered from mouse moving to a corner of the screen. To disable this fail-safe, set pyautogui.FAILSAFE to False. DISABLING FAIL-SAFE IS NOT RECOMMENDED.

# %% [markdown]
# with last before 0.4 went to 11
